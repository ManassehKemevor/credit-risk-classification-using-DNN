# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("loan_risk_multiclass_300.csv")
df.head()
# Out:
#    Age  Income  LoanAmount  CreditScore  EmploymentYears   Debt  Dependents  \
# 0   58    2718       18323          821               12  14414           4
# 1   48    5996       39121          816                9  11801           1
# 2   34    6235       15975          417               11  11745           0
# 3   62    6055       16023          458               29  13025           1
# 4   27    9550       26447          527                1   3356           2
#
#    RiskClass
# 0          2
# 1          2
# 2          0
# 3          0
# 4          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              300 non-null    int64
#  1   Income           300 non-null    int64
#  2   LoanAmount       300 non-null    int64
#  3   CreditScore      300 non-null    int64
#  4   EmploymentYears  300 non-null    int64
#  5   Debt             300 non-null    int64
#  6   Dependents       300 non-null    int64
#  7   RiskClass        300 non-null    int64
# dtypes: int64(8)
# memory usage: 18.9 KB

# %%
x=df.drop("RiskClass",axis=1)
y=df["RiskClass"]
